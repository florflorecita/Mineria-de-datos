# %% [markdown]
# # Práctica_1.3_primera_exploración_a_los_datos_(Clasificacion)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mpl
import missingno as msno

# %%
df = pd.read_csv("datos_clasif_Videojuegos.csv")
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.shape
# Out:
# (16598, 11)

# %%
df.columns.values.tolist()
# Out:
# ['Rank',
#  'Name',
#  'Platform',
#  'Year',
#  'Genre',
#  'Publisher',
#  'NA_Sales',
#  'EU_Sales',
#  'JP_Sales',
#  'Other_Sales',
#  'Global_Sales']

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df)
# Out:
# <AxesSubplot:>

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['Year', 'Publisher']

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# max       10.570000     82.740000

# %%
df.loc[[0]]
# Out:
#    Rank        Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74

# %%
df["Genre"].loc[[100]]
# Out:
# 100    Action
# Name: Genre, dtype: object

# %%
df.loc[1000:1050]
# Out:
#       Rank                                               Name Platform  \
# 1000  1002                         The Urbz: Sims in the City      PS2
# 1001  1003                                     FIFA Soccer 08      PS3
# 1002  1004                             Star Wars: Starfighter      PS2
# 1003  1005                                    Madden NFL 2000       PS
# 1004  1006                                     Kingdom Hearts      PS3
# 1005  1007                             Star Wars: Battlefront       XB
# 1006  1008                               Pro Evolution Soccer      PS2
# 1007  1009                                          Crackdown     X360
# 1008  1010                                              Yoshi      NES
# 1009  1011                                   Disney's Aladdin     SNES
# 1010  1012                                  Kirby's Adventure      NES
# 1011  1013                        Cooking Mama 3: Shop & Chop       DS
# 1012  1014                           Dance Dance Revolution X      PS2
# 1013  1015      2 Games in 1: Disney Princess & The Lion King      GBA
# 1014  1016            Star Wars Episode I: The Phantom Menace       PS
# 1015  1017            Xenosaga Episode I: Der Wille zur Macht      PS2
# 1016  1018                                           Portal 2      PS3
# 1017  1019                             The Beatles: Rock Band      Wii
# 1018  1020                                 Forza Motorsport 6     XOne
# 1019  1021                                       Sonic Colors      Wii
# 1020  1022                                        Cruis'n USA      N64
# 1021  1023                                      Madden NFL 99       PS
# 1022  1024                                         Diablo III      PS4
# 1023  1025                            Uncharted: Golden Abyss      PSV
# 1024  1026                                            Destiny      PS3
# 1025  1027                                         SSX Tricky      PS2
# 1026  1028                                          Overwatch      PS4
# 1027  1029                                  Twisted Metal III       PS
# 1028  1030              Harry Potter and the Sorcerer's Stone       GB
# 1029  1031                                    Disney Infinity      Wii
# 1030  1032                Crash Bandicoot: The Huge Adventure      GBA
# 1031  1033                                         Dishonored     X360
# 1032  1034  Rockstar Games Double Pack: Grand Theft Auto I...      PS2
# 1033  1035                                    The Order: 1886      PS4
# 1034  1036                           The Elder Scrolls Online      PS4
# 1035  1037            Call of Duty: World at War Final Fronts      PS2
# 1036  1038                                   Imagine: Teacher       DS
# 1037  1039                     Call of Duty: Modern Warfare 3       PC
# 1038  1040                                    Madden NFL 2005       XB
# 1039  1041                   Star Ocean: Till The End of Time      PS2
# 1040  1042              The Sims 3: Late Night Expansion Pack       PC
# 1041  1043                                       Game Party 3      Wii
# 1042  1044         Toy Story 2: Buzz Lightyear to the Rescue!       PS
# 1043  1045                                    Deal or No Deal       DS
# 1044  1046                       Ace Combat 5: The Unsung War      PS2
# 1045  1047                         Need for Speed Underground       XB
# 1046  1048  Kanshuu Nippon Joushikiryoku Kentei Kyoukai: I...       DS
# 1047  1049                                      Tetris Worlds      GBA
# 1048  1050                      Cabela's Big Game Hunter 2010      Wii
# 1049  1051                                           The Crew      PS4
# 1050  1052                                     FIFA Soccer 10      PS2
#
#         Year         Genre                               Publisher  NA_Sales  \
# 1000  2004.0    Simulation                         Electronic Arts      0.52
# 1001  2007.0        Sports                         Electronic Arts      0.35
# 1002  2001.0    Simulation                              Activision      0.61
# 1003  1998.0        Sports                         Electronic Arts      1.68
# 1004  2013.0  Role-Playing                             Square Enix      0.90
# 1005  2004.0       Shooter                              Activision      1.24
# 1006  2001.0        Sports            Konami Digital Entertainment      0.06
# 1007  2007.0       Shooter                  Microsoft Game Studios      1.00
# 1008  1991.0        Puzzle                                Nintendo      0.70
# 1009  1993.0      Platform                                  Capcom      0.94
# 1010  1993.0      Platform                                Nintendo      0.79
# 1011  2009.0    Simulation                               505 Games      0.83
# 1012  2008.0    Simulation            Konami Digital Entertainment      0.85
# 1013  2004.0          Misc                                     THQ      1.25
# 1014  1999.0     Adventure                               LucasArts      0.72
# 1015  2002.0  Role-Playing                      Namco Bandai Games      0.63
# 1016  2011.0       Shooter                                   Valve      0.83
# 1017  2009.0          Misc                               MTV Games      1.19
# 1018  2015.0        Racing                  Microsoft Game Studios      0.69
# 1019  2010.0      Platform                                    Sega      0.96
# 1020  1996.0        Racing                                Nintendo      1.69
# 1021  1998.0        Sports                         Electronic Arts      1.66
# 1022  2014.0  Role-Playing                              Activision      0.49
# 1023  2011.0       Shooter             Sony Computer Entertainment      0.59
# 1024  2014.0       Shooter                              Activision      0.67
# 1025  2001.0        Sports                         Electronic Arts      0.85
# 1026  2016.0       Shooter                              Activision      0.64
# 1027  1998.0        Action                             989 Studios      1.48
# 1028  2001.0        Action                         Electronic Arts      0.94
# 1029  2013.0        Action              Disney Interactive Studios      1.15
# 1030  2002.0      Platform                   Universal Interactive      0.95
# 1031  2012.0        Action                      Bethesda Softworks      1.06
# 1032  2003.0        Action                    Take-Two Interactive      0.85
# 1033  2015.0       Shooter             Sony Computer Entertainment      0.61
# 1034  2015.0  Role-Playing                      Bethesda Softworks      0.66
# 1035  2008.0       Shooter                              Activision      0.61
# 1036  2008.0    Simulation                                 Ubisoft      0.70
# 1037  2011.0       Shooter                              Activision      0.41
# 1038  2004.0        Sports                         Electronic Arts      1.61
# 1039  2003.0  Role-Playing                                 Ubisoft      0.80
# 1040  2010.0    Simulation                         Electronic Arts      0.59
# 1041  2009.0        Puzzle  Warner Bros. Interactive Entertainment      1.43
# 1042  1998.0      Platform                              Activision      0.99
# 1043  2007.0          Misc                               Mindscape      1.15
# 1044  2004.0    Simulation      Sony Computer Entertainment Europe      0.88
# 1045  2003.0        Racing                         Electronic Arts      1.09
# 1046  2006.0          Misc                                Nintendo      0.00
# 1047  2001.0        Puzzle                                     THQ      1.25
# 1048  2009.0        Sports                        Activision Value      1.58
# 1049  2014.0        Racing                                 Ubisoft      0.34
# 1050  2009.0        Sports                         Electronic Arts      0.23
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 1000      0.95      0.00         0.29          1.76
# 1001      1.07      0.02         0.32          1.76
# 1002      0.87      0.02         0.26          1.76
# 1003      0.04      0.00         0.04          1.75
# 1004      0.37      0.25         0.24          1.75
# 1005      0.45      0.00         0.07          1.75
# 1006      0.90      0.53         0.27          1.75
# 1007      0.54      0.03         0.18          1.75
# 1008      0.13      0.91         0.01          1.75
# 1009      0.34      0.21         0.27          1.75
# 1010      0.14      0.80         0.02          1.75
# 1011      0.66      0.08         0.18          1.75
# 1012      0.66      0.01         0.22          1.75
# 1013      0.46      0.00         0.03          1.75
# 1014      0.89      0.04         0.10          1.74
# 1015      0.49      0.45         0.17          1.74
# 1016      0.63      0.02         0.25          1.74
# 1017      0.40      0.00         0.16          1.74
# 1018      0.89      0.03         0.14          1.74
# 1019      0.61      0.01         0.16          1.74
# 1020      0.04      0.00         0.01          1.74
# 1021      0.04      0.00         0.04          1.74
# 1022      0.88      0.06         0.30          1.74
# 1023      0.75      0.13         0.27          1.74
# 1024      0.66      0.12         0.27          1.73
# 1025      0.66      0.00         0.22          1.73
# 1026      0.68      0.14         0.26          1.73
# 1027      0.20      0.00         0.05          1.73
# 1028      0.62      0.10         0.07          1.73
# 1029      0.44      0.00         0.14          1.73
# 1030      0.70      0.00         0.08          1.73
# 1031      0.52      0.01         0.14          1.73
# 1032      0.66      0.00         0.22          1.72
# 1033      0.78      0.06         0.27          1.72
# 1034      0.78      0.00         0.28          1.72
# 1035      0.18      0.00         0.94          1.72
# 1036      0.83      0.00         0.19          1.72
# 1037      0.98      0.00         0.33          1.72
# 1038      0.03      0.00         0.08          1.72
# 1039      0.21      0.55         0.15          1.72
# 1040      0.87      0.00         0.25          1.71
# 1041      0.16      0.00         0.12          1.71
# 1042      0.64      0.00         0.08          1.71
# 1043      0.41      0.00         0.15          1.71
# 1044      0.34      0.32         0.18          1.71
# 1045      0.55      0.00         0.07          1.71
# 1046      0.00      1.71         0.00          1.71
# 1047      0.39      0.00         0.06          1.71
# 1048      0.00      0.00         0.12          1.70
# 1049      1.08      0.03         0.26          1.70
# 1050      0.24      0.00         1.23          1.70

# %%
df.drop([0,1], axis=0).head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                    Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7     New Super Mario Bros.       DS  2006.0      Platform  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37
# 5     23.20      2.26      4.22         0.58         30.26
# 6     11.38      9.23      6.50         2.90         30.01

# %%
df.drop(df.index[1:5], axis=0).head(10)
# Out:
#     Rank                         Name Platform    Year         Genre  \
# 0      1                   Wii Sports      Wii  2006.0        Sports
# 5      6                       Tetris       GB  1989.0        Puzzle
# 6      7        New Super Mario Bros.       DS  2006.0      Platform
# 7      8                     Wii Play      Wii  2006.0          Misc
# 8      9    New Super Mario Bros. Wii      Wii  2009.0      Platform
# 9     10                    Duck Hunt      NES  1984.0       Shooter
# 10    11                   Nintendogs       DS  2005.0    Simulation
# 11    12                Mario Kart DS       DS  2005.0        Racing
# 12    13  Pokemon Gold/Pokemon Silver       GB  1999.0  Role-Playing
# 13    14                      Wii Fit      Wii  2007.0        Sports
#
#    Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0   Nintendo     41.49     29.02      3.77         8.46         82.74
# 5   Nintendo     23.20      2.26      4.22         0.58         30.26
# 6   Nintendo     11.38      9.23      6.50         2.90         30.01
# 7   Nintendo     14.03      9.20      2.93         2.85         29.02
# 8   Nintendo     14.59      7.06      4.70         2.26         28.62
# 9   Nintendo     26.93      0.63      0.28         0.47         28.31
# 10  Nintendo      9.07     11.00      1.93         2.75         24.76
# 11  Nintendo      9.81      7.57      4.13         1.92         23.42
# 12  Nintendo      9.00      6.18      7.20         0.71         23.10
# 13  Nintendo      8.94      8.03      3.60         2.15         22.72

# %%
df[100:].head()
# Out:
#      Rank                                    Name Platform    Year    Genre  \
# 100   101  The Legend of Zelda: Twilight Princess      Wii  2006.0   Action
# 101   102               Call of Duty: Black Ops 3     XOne  2015.0  Shooter
# 102   103                              Just Dance      Wii  2009.0     Misc
# 103   104                           Battlefield 3      PS3  2011.0  Shooter
# 104   105              Need for Speed Underground      PS2  2003.0   Racing
#
#            Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 100         Nintendo      3.83      2.19      0.60         0.70          7.31
# 101       Activision      4.52      2.09      0.01         0.67          7.30
# 102          Ubisoft      3.51      3.03      0.00         0.73          7.27
# 103  Electronic Arts      2.85      2.93      0.35         1.10          7.23
# 104  Electronic Arts      3.27      2.83      0.08         1.02          7.20

# %%
df.Platform.value_counts()
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# WS         6
# SCD        6
# 3DO        3
# TG16       2
# PCFX       1
# GG         1
# Name: Platform, dtype: int64

# %%
df.Genre.value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
df[['Genre', "EU_Sales"]].values
# Out:
# array([['Sports', 29.02],
#        ['Platform', 3.58],
#        ['Racing', 12.88],
#        ...,
#        ['Racing', 0.0],
#        ['Puzzle', 0.01],
#        ['Platform', 0.0]], dtype=object)

# %%
df.agg(['count', 'size', 'nunique'])
# Out:
#           Rank   Name  Platform   Year  Genre  Publisher  NA_Sales  EU_Sales  \
# count    16598  16598     16598  16327  16598      16540     16598     16598
# size     16598  16598     16598  16598  16598      16598     16598     16598
# nunique  16598  11493        31     39     12        578       409       305
#
#          JP_Sales  Other_Sales  Global_Sales
# count       16598        16598         16598
# size        16598        16598         16598
# nunique       244          157           623

# %%
df.EU_Sales.values
# Out:
# array([2.902e+01, 3.580e+00, 1.288e+01, ..., 0.000e+00, 1.000e-02,
#        0.000e+00])

# %%
df.groupby('Genre').agg(['count', 'size', 'nunique']).stack()
# Out:
#                       Rank  Name  Platform  Year  Publisher  NA_Sales  \
# Genre
# Action       count    3316  3316      3316  3253       3309      3316
#              size     3316  3316      3316  3316       3316      3316
#              nunique  3316  1925        24    38        228       221
# Adventure    count    1286  1286      1286  1276       1282      1286
#              size     1286  1286      1286  1286       1286      1286
#              nunique  1286  1048        26    28        206        78
# Fighting     count     848   848       848   836        846       848
#              size      848   848       848   848        848       848
#              nunique   848   612        24    29        100       129
# Misc         count    1739  1739      1739  1710       1712      1739
#              size     1739  1739      1739  1739       1739      1739
#              nunique  1739  1327        24    31        210       159
# Platform     count     886   886       886   876        884       886
#              size      886   886       886   886        886       886
#              nunique   886   589        26    36         97       175
# Puzzle       count     582   582       582   571        581       582
#              size      582   582       582   582        582       582
#              nunique   582   499        22    33        116        83
# Racing       count    1249  1249      1249  1226       1248      1249
#              size     1249  1249      1249  1249       1249      1249
#              nunique  1249   772        25    32        128       155
# Role-Playing count    1488  1488      1488  1471       1486      1488
#              size     1488  1488      1488  1488       1488      1488
#              nunique  1488  1219        26    32        158       146
# Shooter      count    1310  1310      1310  1282       1308      1310
#              size     1310  1310      1310  1310       1310      1310
#              nunique  1310   817        25    36        150       199
# Simulation   count     867   867       867   851        863       867
#              size      867   867       867   867        867       867
#              nunique   867   726        23    31        150       117
# Sports       count    2346  2346      2346  2304       2343      2346
#              size     2346  2346      2346  2346       2346      2346
#              nunique  2346  1379        25    37        163       191
# Strategy     count     681   681       681   671        678       681
#              size      681   681       681   681        681       681
#              nunique   681   584        23    26        119        72
#
#                       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Genre
# Action       count        3316      3316         3316          3316
#              size         3316      3316         3316          3316
#              nunique       170        94           86           324
# Adventure    count        1286      1286         1286          1286
#              size         1286      1286         1286          1286
#              nunique        65        50           29           121
# Fighting     count         848       848          848           848
#              size          848       848          848           848
#              nunique        85        77           46           178
# Misc         count        1739      1739         1739          1739
#              size         1739      1739         1739          1739
#              nunique       118        85           65           222
# Platform     count         886       886          886           886
#              size          886       886          886           886
#              nunique       120       101           56           239
# Puzzle       count         582       582          582           582
#              size          582       582          582           582
#              nunique        60        68           27           126
# Racing       count        1249      1249         1249          1249
#              size         1249      1249         1249          1249
#              nunique       125        66           62           218
# Role-Playing count        1488      1488         1488          1488
#              size         1488      1488         1488          1488
#              nunique       106       152           62           246
# Shooter      count        1310      1310         1310          1310
#              size         1310      1310         1310          1310
#              nunique       152        55           83           270
# Simulation   count         867       867          867           867
#              size          867       867          867           867
#              nunique        93        70           39           166
# Sports       count        2346      2346         2346          2346
#              size         2346      2346         2346          2346
#              nunique       139        91           78           273
# Strategy     count         681       681          681           681
#              size          681       681          681           681
#              nunique        55        65           21           109

# %%
list(df['Genre'].unique())
# Out:
# ['Sports',
#  'Platform',
#  'Racing',
#  'Role-Playing',
#  'Puzzle',
#  'Misc',
#  'Shooter',
#  'Simulation',
#  'Action',
#  'Fighting',
#  'Adventure',
#  'Strategy']

# %%
df_dropped = df.dropna(subset=['Year','Publisher'])
df_dropped.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df_dropped.shape
# Out:
# (16291, 11)

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df_copy.shape
# Out:
# (16598, 11)

# %%
df_copy.agg(['count', 'size', 'nunique'])
# Out:
#           Rank   Name  Platform   Year  Genre  Publisher  NA_Sales  EU_Sales  \
# count    16598  16598     16598  16327  16598      16540     16598     16598
# size     16598  16598     16598  16598  16598      16598     16598     16598
# nunique  16598  11493        31     39     12        578       409       305
#
#          JP_Sales  Other_Sales  Global_Sales
# count       16598        16598         16598
# size        16598        16598         16598
# nunique       244          157           623

# %%
df_copy.groupby(["Year", "Genre"]).count()
# Out:
#                      Rank  Name  Platform  Publisher  NA_Sales  EU_Sales  \
# Year   Genre
# 1980.0 Action           1     1         1          1         1         1
#        Fighting         1     1         1          1         1         1
#        Misc             4     4         4          4         4         4
#        Shooter          2     2         2          2         2         2
#        Sports           1     1         1          1         1         1
# ...                   ...   ...       ...        ...       ...       ...
# 2016.0 Sports          38    38        38         38        38        38
#        Strategy        10    10        10         10        10        10
# 2017.0 Action           1     1         1          1         1         1
#        Role-Playing     2     2         2          2         2         2
# 2020.0 Simulation       1     1         1          1         1         1
#
#                      JP_Sales  Other_Sales  Global_Sales
# Year   Genre
# 1980.0 Action               1            1             1
#        Fighting             1            1             1
#        Misc                 4            4             4
#        Shooter              2            2             2
#        Sports               1            1             1
# ...                       ...          ...           ...
# 2016.0 Sports              38           38            38
#        Strategy            10           10            10
# 2017.0 Action               1            1             1
#        Role-Playing         2            2             2
# 2020.0 Simulation           1            1             1
#
# [389 rows x 9 columns]

# %%
df_copy.groupby(["Genre"])[["Platform"]].count()
# Out:
#               Platform
# Genre
# Action            3316
# Adventure         1286
# Fighting           848
# Misc              1739
# Platform           886
# Puzzle             582
# Racing            1249
# Role-Playing      1488
# Shooter           1310
# Simulation         867
# Sports            2346
# Strategy           681

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#         Rank                              Name Platform    Year         Genre  \
# 4234    4236           Razor Freestyle Scooter       PS  1999.0        Sports
# 7119    7121  AC/DC LIVE: Rock Band Track Pack     X360  2008.0          Misc
# 106      107         Crash Bandicoot 3: Warped       PS  1998.0      Platform
# 5242    5244               Company of Heroes 2       PC  2013.0      Strategy
# 13547  13549           Advance Guardian Heroes      GBA  2004.0  Role-Playing
#
#                          Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 4234                       Ubisoft      0.26      0.17      0.00         0.03
# 7119                     MTV Games      0.21      0.00      0.00         0.02
# 106    Sony Computer Entertainment      3.68      1.75      1.42         0.28
# 5242                           THQ      0.06      0.25      0.00         0.05
# 13547                      Ubisoft      0.03      0.01      0.00         0.00
#
#        Global_Sales
# 4234           0.46
# 7119           0.23
# 106            7.13
# 5242           0.36
# 13547          0.04

# %%
df_sample.groupby(["Year", "Genre"])[["EU_Sales", "JP_Sales"]].agg([np.sum, np.mean,np.count_nonzero])
# Out:
#                     EU_Sales                     JP_Sales
#                          sum  mean count_nonzero      sum   mean count_nonzero
# Year   Genre
# 1981.0 Racing           0.03  0.03           1.0     0.00  0.000           0.0
#        Shooter          0.08  0.08           1.0     0.00  0.000           0.0
# 1982.0 Action           0.06  0.02           3.0     0.00  0.000           0.0
#        Sports           0.03  0.03           1.0     0.00  0.000           0.0
# 1986.0 Action           0.26  0.13           1.0     1.18  0.590           2.0
# ...                      ...   ...           ...      ...    ...           ...
# 2016.0 Racing           0.03  0.03           1.0     0.00  0.000           0.0
#        Role-Playing     0.00  0.00           0.0     0.02  0.020           1.0
#        Shooter          0.36  0.18           2.0     0.01  0.005           1.0
#        Sports           0.00  0.00           0.0     0.17  0.170           1.0
#        Strategy         0.03  0.03           1.0     0.00  0.000           0.0
#
# [226 rows x 6 columns]

# %%
mpl.hist(df['Year'])
mpl.title("Frecuencia de ventas por año")
mpl.xlabel("AÑo")
mpl.ylabel("Frecuencia de ventas")
# Out:
# Text(0, 0.5, 'Frecuencia de ventas')

# %%
df_sample['Global_Sales'] = df_sample['Global_Sales'].astype('int64')
df_sample.plot(kind='scatter',x='Global_Sales',y='Platform')
# Out:
# <AxesSubplot:xlabel='Global_Sales', ylabel='Platform'>

# %%
df_sample['Global_Sales'] = df_sample['Global_Sales'].astype('int64')
df_sample.plot(kind='scatter',x='Global_Sales',y='Genre')
# Out:
# <AxesSubplot:xlabel='Global_Sales', ylabel='Genre'>
