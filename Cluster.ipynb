# %% [markdown]
# # Práctica 1 Primera exploración a los datos (Clúster)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mpl
import missingno as msno

# %%
df = pd.read_csv("datos_cluster_Instagram.csv")
df.head()
# Out:
#    RANK                BRAND CATEGORIES 1 CATEGORIES 2  FOLLOWERS      ER  \
# 0     1         Selena Gomez  celebrities    musicians      105.4  0.0262
# 1     2         Taylor Swift  celebrities    musicians       95.2  0.0196
# 2     3        Ariana Grande  celebrities    musicians       92.3  0.0143
# 3     4              Beyonce  celebrities    musicians       90.6  0.0253
# 4     5  Kim Kardashian West  celebrities           tv       89.3  0.0139
#
#   iPOSTS ON HASHTAG  MEDIA POSTED
# 0              14.5           1.2
# 1              10.5         958.0
# 2              16.9           2.8
# 3               9.2           1.4
# 4               5.1           3.6

# %% [markdown]
# ### General Stats

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   RANK               100 non-null    int64
#  1   BRAND              100 non-null    object
#  2   CATEGORIES 1       100 non-null    object
#  3   CATEGORIES 2       91 non-null     object
#  4   FOLLOWERS          100 non-null    float64
#  5   ER                 100 non-null    float64
#  6   iPOSTS ON HASHTAG  100 non-null    object
#  7   MEDIA POSTED       100 non-null    float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 6.4+ KB

# %% [markdown]
# Shape of dataframe

# %%
df.shape
# Out:
# (100, 8)

# %% [markdown]
# Number of rows

# %%
df.shape[0]
# Out:
# 100

# %% [markdown]
# Number of columns

# %%
df.shape[1]
# Out:
# 8

# %% [markdown]
# Column Names

# %%
df.columns.values.tolist()
# Out:
# ['RANK',
#  'BRAND',
#  'CATEGORIES 1',
#  'CATEGORIES 2',
#  'FOLLOWERS',
#  'ER',
#  'iPOSTS ON HASHTAG',
#  'MEDIA POSTED']

# %% [markdown]
# Column Data Types

# %%
df.dtypes
# Out:
# RANK                   int64
# BRAND                 object
# CATEGORIES 1          object
# CATEGORIES 2          object
# FOLLOWERS            float64
# ER                   float64
# iPOSTS ON HASHTAG     object
# MEDIA POSTED         float64
# dtype: object

# %% [markdown]
# Are there missing values?

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df.replace({' ': np.nan}, inplace=True)

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.bar(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# "Columns with Missing Values"

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['CATEGORIES 2']

# %% [markdown]
# Number of rows with Missing Values

# %% [markdown]
# ### Summary Stats

# %%
df.describe()
# Out:
#              RANK   FOLLOWERS          ER  MEDIA POSTED
# count  100.000000  100.000000  100.000000    100.000000
# mean    50.500000   31.047000    0.023907    146.456000
# std     29.011492   24.286828    0.020762    267.758934
# min      1.000000   11.500000    0.004600      1.000000
# 25%     25.750000   13.925000    0.012775      2.250000
# 50%     50.500000   18.250000    0.016500      3.650000
# 75%     75.250000   42.175000    0.027075    155.000000
# max    100.000000  105.400000    0.123000    986.000000

# %% [markdown]
# Select specific row index

# %%
df.loc[[0]]
# Out:
#    RANK         BRAND CATEGORIES 1 CATEGORIES 2  FOLLOWERS      ER  \
# 0     1  Selena Gomez  celebrities    musicians      105.4  0.0262
#
#   iPOSTS ON HASHTAG  MEDIA POSTED
# 0              14.5           1.2

# %%
df.BRAND.loc[[16]]
# Out:
# 16    KATY PERRY
# Name: BRAND, dtype: object

# %%
df["CATEGORIES 1"].loc[[0]]
# Out:
# 0    celebrities
# Name: CATEGORIES 1, dtype: object

# %%
df[["BRAND", "CATEGORIES 1"]].loc[[37]]
# Out:
#            BRAND CATEGORIES 1
# 37  LeBron James  celebrities

# %% [markdown]
# Select specific row indices

# %%
df.loc[31:34]
# Out:
#     RANK          BRAND CATEGORIES 1 CATEGORIES 2  FOLLOWERS      ER  \
# 31    32  David Beckham  celebrities     athletes       31.7  0.0323
# 32    33  champagnepapi  celebrities    musicians       31.1  0.0133
# 33    34     Vin Diesel  celebrities       actors       30.2  0.0176
# 34    35        Shakira  celebrities    musicians       28.4  0.0206
#
#    iPOSTS ON HASHTAG  MEDIA POSTED
# 31              430.         476.0
# 32              306.           3.4
# 33              394k         986.0
# 34              771k         664.0

# %% [markdown]
# Excluding Specific Row indices

# %%
df.drop([0,24,51], axis=0).head()
# Out:
#    RANK                BRAND CATEGORIES 1 CATEGORIES 2  FOLLOWERS      ER  \
# 1     2         Taylor Swift  celebrities    musicians       95.2  0.0196
# 2     3        Ariana Grande  celebrities    musicians       92.3  0.0143
# 3     4              Beyonce  celebrities    musicians       90.6  0.0253
# 4     5  Kim Kardashian West  celebrities           tv       89.3  0.0139
# 5     6    Cristiano Ronaldo  celebrities     athletes       85.1  0.0262
#
#   iPOSTS ON HASHTAG  MEDIA POSTED
# 1              10.5         958.0
# 2              16.9           2.8
# 3               9.2           1.4
# 4               5.1           3.6
# 5               3.6           1.6

# %% [markdown]
# Excluding Specific Range Row indices

# %%
df.drop(df.index[1:5], axis=0).head(10)
# Out:
#     RANK                BRAND CATEGORIES 1 CATEGORIES 2  FOLLOWERS      ER  \
# 0      1         Selena Gomez  celebrities    musicians      105.4  0.0262
# 5      6    Cristiano Ronaldo  celebrities     athletes       85.1  0.0262
# 6      7                Kylie  celebrities       models       81.8  0.0189
# 7      8        Justin Bieber  celebrities    musicians       77.9  0.0166
# 8      9              therock  celebrities     athletes       73.3  0.0124
# 9     10              Kendall  celebrities       models       70.9  0.0178
# 10    11          Nicki Minaj  celebrities    musicians       70.8  0.0093
# 11    12                 nike      fashion        sport       68.2  0.0176
# 12    13  National Geographic        media          NaN       65.8  0.0114
# 13    14                   Nj  celebrities     athletes       64.0  0.0152
#
#    iPOSTS ON HASHTAG  MEDIA POSTED
# 0               14.5           1.2
# 5                3.6           1.6
# 6                6.2           4.9
# ...

# %% [markdown]
# Subsetting based on offset from top (bottom)

# %%
df[15:].head(8) #df.tail(-100) )
# Out:
#     RANK                BRAND CATEGORIES 1 CATEGORIES 2  FOLLOWERS      ER  \
# 15    16                Khloe  celebrities           tv       60.2  0.0216
# 16    17           KATY PERRY  celebrities    musicians       59.6  0.0150
# 17    18          Miley Cyrus  celebrities    musicians       57.8  0.0141
# 18    19       Jennifer Lopez  celebrities    musicians       55.1  0.0123
# 19    20          Demi Lovato  celebrities    musicians       51.3  0.0265
# 20    21  Kourtney Kardashian  celebrities           tv       50.7  0.0124
# 21    22    Victoria's Secret      fashion          NaN       49.1  0.0103
# 22    23           badgalriri  celebrities    musicians       47.3  0.0153
#
#    iPOSTS ON HASHTAG  MEDIA POSTED
# 15               1.4           3.1
# 16               3.3         507.0
# 17                 6           5.8
# 18               1.2           1.6
# 19                 6           1.5
# 20                 1           3.0
# 21               3.5           4.3
# ...

# %%
df["CATEGORIES 1"].values
# Out:
# array(['celebrities', 'celebrities', 'celebrities', 'celebrities',
#        'celebrities', 'celebrities', 'celebrities', 'celebrities',
#        'celebrities', 'celebrities', 'celebrities', 'fashion', 'media',
#        'celebrities', 'celebrities', 'celebrities', 'celebrities',
#        'celebrities', 'celebrities', 'celebrities', 'celebrities',
#        'fashion', 'celebrities', 'celebrities', 'sport', 'sport',
#        'celebrities', 'celebrities', 'celebrities', 'celebrities',
#        'entertainment', 'celebrities', 'celebrities', 'celebrities',
#        'celebrities', 'celebrities', 'celebrities', 'celebrities',
#        'celebrities', 'fashion', 'celebrities', 'celebrities',
#        'celebrities', 'celebrities', 'celebrities', 'sport',
#        'celebrities', 'celebrities', 'celebrities', 'celebrities',
#        'other', 'fashion', 'celebrities', 'celebrities', 'fashion',
#        'celebrities', 'celebrities', 'celebrities', 'celebrities',
# ...

# %%
df[["BRAND","CATEGORIES 2"]].values
# Out:
# array([['Selena Gomez', 'musicians'],
#        ['Taylor Swift', 'musicians'],
#        ['Ariana Grande', 'musicians'],
#        ['Beyonce', 'musicians'],
#        ['Kim Kardashian West', 'tv'],
#        ['Cristiano Ronaldo', 'athletes'],
#        ['Kylie', 'models'],
#        ['Justin Bieber', 'musicians'],
#        ['therock', 'athletes'],
#        ['Kendall', 'models'],
#        ['Nicki Minaj', 'musicians'],
#        ['nike', 'sport'],
#        ['National Geographic', nan],
#        ['Nj', 'athletes'],
#        ['Leo Messi', 'athletes'],
#        ['Khloe', 'tv'],
#        ['KATY PERRY', 'musicians'],
#        ['Miley Cyrus', 'musicians'],
#        ['Jennifer Lopez', 'musicians'],
#        ['Demi Lovato', 'musicians'],
#        ['Kourtney Kardashian', 'tv'],
#        ["Victoria's Secret", nan],
#        ['badgalriri', 'musicians'],
#        ['Kevin Hart', 'actors'],
#        ['FC Barcelona', 'football'],
#        ['Real Madrid C.F.', 'football'],
# ...

# %%
df["CATEGORIES 1"].unique()
# Out:
# array(['celebrities', 'fashion', 'media', 'sport', 'entertainment',
#        'other', 'beauty', 'beverages'], dtype=object)

# %%
df["CATEGORIES 1"].nunique()
# Out:
# 8

# %%
df["CATEGORIES 1"].value_counts()
# Out:
# celebrities      75
# fashion          13
# sport             4
# media             3
# beauty            2
# entertainment     1
# beverages         1
# other             1
# Name: CATEGORIES 1, dtype: int64

# %%
df.agg(['count', 'size', 'nunique'])
# Out:
#          RANK  BRAND  CATEGORIES 1  CATEGORIES 2  FOLLOWERS   ER  \
# count     100    100           100            91        100  100
# size      100    100           100           100        100  100
# nunique   100    100             8            14         85   85
#
#          iPOSTS ON HASHTAG  MEDIA POSTED
# count                  100           100
# size                   100           100
# nunique                 87            67

# %%
df.groupby('CATEGORIES 1').agg(['count', 'size', 'nunique']).stack()
# Out:
#                        RANK  BRAND  CATEGORIES 2  FOLLOWERS  ER  \
# CATEGORIES 1
# beauty        count       2      2             1          2   2
#               size        2      2             2          2   2
#               nunique     2      2             1          2   2
# beverages     count       1      1             0          1   1
#               size        1      1             1          1   1
#               nunique     1      1             0          1   1
# celebrities   count      75     75            75         75  75
#               size       75     75            75         75  75
#               nunique    75     75             9         65  67
# entertainment count       1      1             0          1   1
#               size        1      1             1          1   1
#               nunique     1      1             0          1   1
# fashion       count      13     13            11         13  13
# ...

# %%
df.groupby('CATEGORIES 1').agg(['count', 'size', 'nunique'])
# Out:
#                RANK              BRAND              CATEGORIES 2               \
#               count size nunique count size nunique        count size nunique
# CATEGORIES 1
# beauty            2    2       2     2    2       2            1    2       1
# beverages         1    1       1     1    1       1            0    1       0
# celebrities      75   75      75    75   75      75           75   75       9
# entertainment     1    1       1     1    1       1            0    1       0
# fashion          13   13      13    13   13      13           11   13       3
# media             3    3       3     3    3       3            0    3       0
# other             1    1       1     1    1       1            0    1       0
# sport             4    4       4     4    4       4            4    4       2
#
#               FOLLOWERS  ...            ER              iPOSTS ON HASHTAG  \
#                   count  ... nunique count size nunique             count
# ...

# %%
df_sample = df.sample(frac=0.25, random_state=1)
df_sample.head()
# Out:
#     RANK            BRAND CATEGORIES 1 CATEGORIES 2  FOLLOWERS      ER  \
# 80    81    Dior Official      fashion       luxury       13.1  0.0074
# 84    85    elliegoulding  celebrities    musicians       12.9  0.0175
# 33    34       Vin Diesel  celebrities       actors       30.2  0.0176
# 81    82  M‡A‡C Cosmetics       beauty       retail       13.0  0.0070
# 93    94  Louis Tomlinson  celebrities    musicians       11.8  0.1140
#
#    iPOSTS ON HASHTAG  MEDIA POSTED
# 80              34.4           1.9
# 84              648.           3.6
# 33              394k         986.0
# 81               7.6           3.3
# 93              25.5         148.0

# %%
df.shape
# Out:
# (100, 8)

# %%
df_sample.shape
# Out:
# (25, 8)

# %% [markdown]
# ### Data Transform

# %% [markdown]
# Drop Rows with missing count

# %%
df_dropped = df.dropna(subset=['CATEGORIES 2'])
df_dropped.head()
# Out:
#    RANK                BRAND CATEGORIES 1 CATEGORIES 2  FOLLOWERS      ER  \
# 0     1         Selena Gomez  celebrities    musicians      105.4  0.0262
# 1     2         Taylor Swift  celebrities    musicians       95.2  0.0196
# 2     3        Ariana Grande  celebrities    musicians       92.3  0.0143
# 3     4              Beyonce  celebrities    musicians       90.6  0.0253
# 4     5  Kim Kardashian West  celebrities           tv       89.3  0.0139
#
#   iPOSTS ON HASHTAG  MEDIA POSTED
# 0              14.5           1.2
# 1              10.5         958.0
# 2              16.9           2.8
# 3               9.2           1.4
# 4               5.1           3.6

# %%
df_dropped.shape
# Out:
# (91, 8)

# %% [markdown]
# Copy of df

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#    RANK                BRAND CATEGORIES 1 CATEGORIES 2  FOLLOWERS      ER  \
# 0     1         Selena Gomez  celebrities    musicians      105.4  0.0262
# 1     2         Taylor Swift  celebrities    musicians       95.2  0.0196
# 2     3        Ariana Grande  celebrities    musicians       92.3  0.0143
# 3     4              Beyonce  celebrities    musicians       90.6  0.0253
# 4     5  Kim Kardashian West  celebrities           tv       89.3  0.0139
#
#   iPOSTS ON HASHTAG  MEDIA POSTED
# 0              14.5           1.2
# 1              10.5         958.0
# 2              16.9           2.8
# 3               9.2           1.4
# 4               5.1           3.6

# %%
df_copy.shape
# Out:
# (100, 8)

# %%
df_dropped['ER'].dtype
# Out:
# dtype('float64')

# %%
df_dropped['FOLLOWERS'].mean()
# Out:
# 31.556043956043954

# %%
df_copy['FOLLOWERS'].fillna(value=np.round(df['FOLLOWERS'].mean(),decimals=0), inplace=True)

# %%
df_copy.agg(['count', 'size', 'nunique'])
# Out:
#          RANK  BRAND  CATEGORIES 1  CATEGORIES 2  FOLLOWERS   ER  \
# count     100    100           100            91        100  100
# size      100    100           100           100        100  100
# nunique   100    100             8            14         85   85
#
#          iPOSTS ON HASHTAG  MEDIA POSTED
# count                  100           100
# size                   100           100
# nunique                 87            67

# %% [markdown]
# ### Handling Categorical Data

# %%
list(df['CATEGORIES 1'].unique())
# Out:
# ['celebrities',
#  'fashion',
#  'media',
#  'sport',
#  'entertainment',
#  'other',
#  'beauty',
#  'beverages']

# %%
df['CATEGORIES 1'].replace({'celebrities':"Celeb",
 'fashion':"FS",
 'media':"MD",
 'sport':"Sp",
 'entertainment':"ETM",
 'other':"Ot",
 'beauty':"Beau",
 'beverages':"Bev"}, inplace=True)

# %%
list(df['CATEGORIES 1'].unique())
# Out:
# ['Celeb', 'FS', 'MD', 'Sp', 'ETM', 'Ot', 'Beau', 'Bev']

# %% [markdown]
# Create a dictionary

# %%
keys = list(df['CATEGORIES 1'].unique())
vals = range(1,10)
act = dict(zip(keys, vals))
act
# Out:
# {'Celeb': 1, 'FS': 2, 'MD': 3, 'Sp': 4, 'ETM': 5, 'Ot': 6, 'Beau': 7, 'Bev': 8}

# %%
df_copy['CATEGORIES 3'] = df['CATEGORIES 1'].map(act)
df_copy.head(15)
# Out:
#     RANK                BRAND CATEGORIES 1 CATEGORIES 2  FOLLOWERS      ER  \
# 0      1         Selena Gomez  celebrities    musicians      105.4  0.0262
# 1      2         Taylor Swift  celebrities    musicians       95.2  0.0196
# 2      3        Ariana Grande  celebrities    musicians       92.3  0.0143
# 3      4              Beyonce  celebrities    musicians       90.6  0.0253
# 4      5  Kim Kardashian West  celebrities           tv       89.3  0.0139
# 5      6    Cristiano Ronaldo  celebrities     athletes       85.1  0.0262
# 6      7                Kylie  celebrities       models       81.8  0.0189
# 7      8        Justin Bieber  celebrities    musicians       77.9  0.0166
# 8      9              therock  celebrities     athletes       73.3  0.0124
# 9     10              Kendall  celebrities       models       70.9  0.0178
# 10    11          Nicki Minaj  celebrities    musicians       70.8  0.0093
# ...

# %%
list(df_copy['CATEGORIES 3'].unique())
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# ### Data Summarization

# %% [markdown]
# Preparing a compact representation of raw data at hand
#
# Aggregation of data using different statistical, mathematical, and other methods.
# Summarization is helpful for visualization, compressing raw data, and better understanding of its attributes.

# %%
df_copy['FOLLOWERS'].mean()
# Out:
# 31.046999999999997

# %%
df_copy['FOLLOWERS'][df_copy['CATEGORIES 3'] == 2]
# Out:
# 11    68.2
# 21    49.1
# 39    25.0
# 51    18.1
# 54    17.1
# 60    16.3
# 64    15.2
# 72    14.2
# 80    13.1
# 90    12.1
# 91    12.1
# 92    12.0
# 96    11.7
# Name: FOLLOWERS, dtype: float64

# %%
df_copy['FOLLOWERS'][df_copy['CATEGORIES 3'] == 2].mean()
# Out:
# 21.861538461538462

# %%
df_copy.groupby(["CATEGORIES 3", "CATEGORIES 1", "CATEGORIES 2"]).count()
# Out:
#                                          RANK  BRAND  FOLLOWERS  ER  \
# CATEGORIES 3 CATEGORIES 1 CATEGORIES 2
# 1            celebrities  actors           11     11         11  11
#                           athletes         18     18         18  18
#                           entrepreneurs     1      1          1   1
#                           fashion           1      1          1   1
#                           media             1      1          1   1
#                           models            5      5          5   5
#                           musicians        30     30         30  30
#                           political         1      1          1   1
#                           tv                7      7          7   7
# 2            fashion      luxury            5      5          5   5
#                           retail            2      2          2   2
#                           sport             4      4          4   4
# ...

# %%
df_copy.groupby(["CATEGORIES 1", "BRAND"])[["FOLLOWERS", "MEDIA POSTED"]].count()
# Out:
#                                       FOLLOWERS  MEDIA POSTED
# CATEGORIES 1 BRAND
# beauty       Anastasia Beverly Hills          1             1
#              M‡A‡C Cosmetics                  1             1
# beverages    Starbucks Coffee                 1             1
# celebrities  50 Cent                          1             1
#              Andres Iniesta                   1             1
# ...                                         ...           ...
# other        NASA                             1             1
# sport        FC Barcelona                     1             1
#              Manchester United                1             1
#              NBA                              1             1
#              Real Madrid C.F.                 1             1
#
# [100 rows x 2 columns]

# %%
df_copy["CATEGORIES 2"]
# Out:
# 0     musicians
# 1     musicians
# 2     musicians
# 3     musicians
# 4            tv
#         ...
# 95     athletes
# 96       luxury
# 97    musicians
# 98     athletes
# 99    political
# Name: CATEGORIES 2, Length: 100, dtype: object

# %%
df_sample = df.sample(frac=0.25, random_state=1)
df_sample.head()
# Out:
#     RANK            BRAND CATEGORIES 1 CATEGORIES 2  FOLLOWERS      ER  \
# 80    81    Dior Official           FS       luxury       13.1  0.0074
# 84    85    elliegoulding        Celeb    musicians       12.9  0.0175
# 33    34       Vin Diesel        Celeb       actors       30.2  0.0176
# 81    82  M‡A‡C Cosmetics         Beau       retail       13.0  0.0070
# 93    94  Louis Tomlinson        Celeb    musicians       11.8  0.1140
#
#    iPOSTS ON HASHTAG  MEDIA POSTED
# 80              34.4           1.9
# 84              648.           3.6
# 33              394k         986.0
# 81               7.6           3.3
# 93              25.5         148.0

# %%
# variant-1: multiple aggregations on single attribute
df_sample.groupby(["CATEGORIES 1", "BRAND"])[["FOLLOWERS", "MEDIA POSTED"]].agg([np.sum, np.mean,np.count_nonzero])
# Out:
#                                     FOLLOWERS                      \
#                                           sum  mean count_nonzero
# CATEGORIES 1 BRAND
# Beau         M‡A‡C Cosmetics             13.0  13.0           1.0
# Celeb        Andres Iniesta              15.3  15.3           1.0
#              Ariana Grande               92.3  92.3           1.0
#              Bruna Marquezine _          17.7  17.7           1.0
#              Channing Tatum              13.0  13.0           1.0
#              Ciara                       14.6  14.6           1.0
#              Daddy Yankee                13.3  13.3           1.0
#              David Beckham               31.7  31.7           1.0
#              Demi Lovato                 51.3  51.3           1.0
#              Gigi Hadid                  27.2  27.2           1.0
#              Louis Tomlinson             11.8  11.8           1.0
#              Lucy Hale                   16.6  16.6           1.0
# ...

# %%
# variant-2: different aggregation functions for each attribute 

df_sample.groupby(["CATEGORIES 1", "BRAND"]).agg({'FOLLOWERS':np.mean,'MEDIA POSTED':np.max})
# Out:
#                                      FOLLOWERS  MEDIA POSTED
# CATEGORIES 1 BRAND
# Beau         M‡A‡C Cosmetics              13.0           3.3
# Celeb        Andres Iniesta               15.3         378.0
#              Ariana Grande                92.3           2.8
#              Bruna Marquezine _           17.7           2.3
#              Channing Tatum               13.0         718.0
#              Ciara                        14.6           2.9
#              Daddy Yankee                 13.3           3.2
#              David Beckham                31.7         476.0
#              Demi Lovato                  51.3           1.5
#              Gigi Hadid                   27.2           2.3
#              Louis Tomlinson              11.8         148.0
#              Lucy Hale                    16.6           3.0
#              Miley Cyrus                  57.8           5.8
#              Nicki Minaj                  70.8           4.2
# ...

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# #### Scatter plots

# %% [markdown]
# Variables able to be highly correlated. To confirm or validate our hypothesis.

# %%
df_sample['FOLLOWERS'] = df_sample['FOLLOWERS'].astype('int64')

df_sample.plot(kind='scatter',x='FOLLOWERS',y='CATEGORIES 1')
# Out:
# <AxesSubplot:xlabel='FOLLOWERS', ylabel='CATEGORIES 1'>

# %%
df_sample['FOLLOWERS'] = df_sample['FOLLOWERS'].astype('int64')

df_sample.plot(kind='scatter',x='FOLLOWERS',y='CATEGORIES 2')
# Out:
# <AxesSubplot:xlabel='FOLLOWERS', ylabel='CATEGORIES 2'>

# %% [markdown]
# #### Histograms

# %% [markdown]
# Plotting histograms is a great way to visualize the distribution of a numerical variable.
# Plotting a histogram is a method to understand the most frequent ranges (or bins as they are called) in which the variable lies.
# One can also check whether the variable is normally distributed or skewed on one side.

# %%
mpl.hist(df_copy['CATEGORIES 3'])
mpl.xlabel('CATEGORIES 3')
mpl.ylabel('FREQUIENCY')
mpl.title('Frequency of CATEGORIES 3')
# Out:
# Text(0.5, 1.0, 'Frequency of CATEGORIES 3')

# %%
mpl.hist(df_copy['FOLLOWERS'])
mpl.xlabel('FOLLOWERS')
mpl.ylabel('FREQUIENCY')
mpl.title('Frequency of FOLLOWERS')
# Out:
# Text(0.5, 1.0, 'Frequency of FOLLOWERS')

# %% [markdown]
# #### Boxplots

# %% [markdown]
# Boxplots are another way to understand the distribution of a numerical variable. It specifies something called quartiles.
#
# If the numbers in a distribution with 100 numbers are arranged in an increasing order;
#
#     * The 1st quartile will occupy the 25th position,
#     * The 3rd quartile will occupy the 75th position, and so on.
#     * The median will be the average of the 50th and 51st terms.
#     * Median is the middle term when the numbers in the distribution are arranged in the increasing order.
#     * Mode is the one that occurs with the maximum frequency, while mean is the sum of all the numbers divided by their total count.

# %%
mpl.boxplot(df_sample['FOLLOWERS'], showmeans=True, meanline=True)
mpl.ylabel('FOLLOWERS count')
mpl.title('Box Plot of FOLLOWERS count')
# Out:
# Text(0.5, 1.0, 'Box Plot of FOLLOWERS count')
